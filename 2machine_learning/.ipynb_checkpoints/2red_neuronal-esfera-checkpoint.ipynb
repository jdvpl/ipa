# %%
import tensorflow as tf
import numpy as np

import matplotlib.pyplot as plt

# %%
sphereRadius = np.array([0, 1, 2,3,5, 10, 11,20], dtype=float)

# %%
sphereVolumeOutput = np.array([0, 1, 8,27,125, 1000,1331,8000], dtype=float)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=[1]),
    tf.keras.layers.Dense(units=3),abs    
    tf.keras.layers.Dense(units=1)

])

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(0.1),
    loss='mean_squared_error'
)

# %%
print("starting training...")
history = model.fit(sphereRadius, sphereVolumeOutput, epochs=3000, verbose=False)
print("model trained...")
# Out:
# starting training...
# model trained...

# %%
plt.xlabel("# epoch")
plt.ylabel("# lost magnitude")
plt.plot(history.history['loss'])

# %%
print("Prediction for model")
result=model.predict(np.array([21]))
print("result is"+str(result))
# Out:
# Prediction for model
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# result is[[1999.9783]]

# %%
dense_layer = model.layers
for data in dense_layer:
    weights, biases = data.get_weights()
    print(f"Pesos: {weights}")
    print(f"Sesgos: {biases}")
# Out:
# Pesos: [[-1.0403037   1.5734186   0.8651652  -1.0758786   1.4690646   1.092043
#   -1.5368475   1.1257467   0.9623898  -1.5057244   0.89448255 -1.208062
#   -1.2892033  -1.3052794   1.2722936 ]]
# Sesgos: [ 11.114441  -10.884436  -11.048375   11.0759535 -10.927103  -11.074291
#   10.912968  -11.33455   -11.371097   10.94065   -11.063504   11.438149
#   10.921874   10.960978  -10.964571 ]
# Pesos: [[ 1.228889    1.802405   -1.1751425  -1.2930932  -0.591708   -1.3925583
#   -1.8254489  -0.11670687 -0.41265658 -1.8712674  -1.0870136   1.4055357
#   -1.6484803  -1.3383664  -1.4467897 ]
#  [-1.8609878  -1.4823102   1.4631588   2.1660779   0.65189093  2.3085642
#    2.3896048   0.09317602  0.89546865  2.4631016   2.1370983  -2.295645
#    1.9356248   2.090031    1.6384012 ]
#  [-1.6654946  -1.0973123   0.4587172   0.8667931   0.2374998   1.3543289
#    1.4631431   0.02333376  0.03487056  1.6260622   1.2707303  -1.3469169
#    1.3834305   1.0580593   0.975796  ]
#  [ 1.9983463   1.3619845  -1.2400243  -1.0403947  -0.5528061  -1.5873148
#   -1.8584061  -0.4067686  -0.41872388 -1.2194134  -1.3456726   1.7477081
#   -1.8237038  -1.2481022  -1.5385076 ]
#  [-2.271545   -1.4224894   1.1431067   2.106476    0.5409598   2.3882468
#    2.108538   -0.4038637   0.8237832   2.0500863   1.5545795  -2.2504
#    2.0312765   1.4414669   2.091293  ]
#  [-1.7618866  -1.6265241   1.0593725   1.625497    0.70003706  2.0948825
#    1.2842911  -0.05744095  0.20481403  1.5058743   1.1510732  -1.950003
#    1.7413903   0.99147576  1.4454762 ]
#  [ 2.3997655   1.7854431  -1.2191207  -1.5611821  -0.6064234  -2.378483
#   -2.3267384  -0.07046656 -0.9077506  -2.263634   -2.2349162   1.9529448
#   -1.7779679  -1.4500005  -2.0729268 ]
#  [-1.6398673  -1.82234     0.52136153  1.7459452   1.0045336   1.6827117
#    1.8614106  -0.3316839   0.5927954   1.3899267   1.5353376  -1.9039007
#    2.0056288   1.4753733   1.7518679 ]
#  [-1.678358   -1.0679011   0.3503747   1.3824764   0.41890752  1.482634
#    1.8468194  -0.11872592 -0.14564294  1.733297    1.7181941  -1.3295547
#    1.2716691   1.3343384   1.493775  ]
#  [ 2.065915    2.0976968  -0.90835667 -1.591927   -1.1687467  -2.3980637
#   -2.4218109   0.46581012 -0.48269013 -1.6661539  -2.3288517   2.3101954
#   -1.6465741  -2.0979896  -1.5075089 ]
#  [-0.9807906  -1.4388549   0.9083911   0.782059    0.6199087   1.5979795
#    1.8152217  -0.04089323  0.12006643  1.748705    1.1057848  -1.0165184
#    0.7930699   1.1727899   1.7020249 ]
