# %%
import pandas as pd

# %%
df=pd.read_csv(r'./files/causeofdeath.csv',delimiter=",",encoding="ISO-8859-1")

# %%
df_filtered = df[df['Year'] != "2017"]

df.head()
# Out:
#   Location         Year       Age   Sex Cause of death or injury  \
# 0   Global         2017  All ages  Both             Tuberculosis
# 1   Global  2005 - 2010  All ages  Both             Tuberculosis
# 2   Global         2017  All ages  Both                 HIV/AIDS
# 3   Global  2005 - 2010  All ages  Both                 HIV/AIDS
# 4   Global         2017  All ages  Both       Diarrheal diseases
#
#                    Measure     Value  Lower bound  Upper bound
# 0  Percent of total deaths  0.021157     0.020229     0.022217
# 1   Deaths annual % change -0.032549          NaN          NaN
# 2  Percent of total deaths  0.017061     0.016189     0.018019
# 3   Deaths annual % change -0.045663          NaN          NaN
# 4  Percent of total deaths  0.028053     0.021061     0.039013

# %%
df_filtered.head(50)
# Out:
#    Location         Year       Age   Sex  \
# 1    Global  2005 - 2010  All ages  Both
# 3    Global  2005 - 2010  All ages  Both
# 5    Global  2005 - 2010  All ages  Both
# 7    Global  2005 - 2010  All ages  Both
# 9    Global  2005 - 2010  All ages  Both
# 11   Global  2005 - 2010  All ages  Both
# 13   Global  2005 - 2010  All ages  Both
# 15   Global  2005 - 2010  All ages  Both
# 17   Global  2005 - 2010  All ages  Both
# 19   Global  2005 - 2010  All ages  Both
# 21   Global  2005 - 2010  All ages  Both
# 23   Global  2005 - 2010  All ages  Both
# 25   Global  2005 - 2010  All ages  Both
# 27   Global  2005 - 2010  All ages  Both
# 29   Global  2005 - 2010  All ages  Both
# 31   Global  2005 - 2010  All ages  Both
# 33   Global  2005 - 2010  All ages  Both
# 35   Global  2005 - 2010  All ages  Both
# 37   Global  2005 - 2010  All ages  Both
# 39   Global  2005 - 2010  All ages  Both
# 41   Global  2005 - 2010  All ages  Both
# 43   Global  2005 - 2010  All ages  Both
# ...

# %%
df_filtered.to_csv(r'./files/causeofdeath_2005.csv', index=False)
